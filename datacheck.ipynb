# %%
import pandas as pd

# %%
df = pd.read_csv("data/amazon_reviews.txt", sep="\t")

# %%
pd.unique(df["PRODUCT_ID"]).__len__()
# Out:
# 18857

# %%
df = pd.read_csv("data/transformed/df.csv", sep=",")

df.describe()
# Out:
#          Unnamed: 0        rating      verified         cat_0         cat_1  \
# count  18107.000000  18107.000000  18107.000000  18107.000000  18107.000000
# mean    9053.000000      4.116750      0.555476      0.033854      0.033136
# std     5227.184998      1.271956      0.496927      0.180859      0.178998
# min        0.000000      1.000000      0.000000      0.000000      0.000000
# 25%     4526.500000      4.000000      0.000000      0.000000      0.000000
# 50%     9053.000000      5.000000      1.000000      0.000000      0.000000
# 75%    13579.500000      5.000000      1.000000      0.000000      0.000000
# max    18106.000000      5.000000      1.000000      1.000000      1.000000
#
#               cat_2         cat_3         cat_4         cat_5         cat_6  \
# count  18107.000000  18107.000000  18107.000000  18107.000000  18107.000000
# mean       0.029160      0.032474      0.038217      0.032860      0.030375
# ...
