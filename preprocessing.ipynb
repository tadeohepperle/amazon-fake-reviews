# %%
import pandas as pd
import numpy as np
import textblob

# %%
df = pd.read_csv("data/amazon_reviews.txt", sep="\t")
df = df.rename(columns={"PRODUCT_ID": "product_id", "PRODUCT_TITLE": "product_title","REVIEW_TITLE": "review_title","REVIEW_TEXT": "review_text", "VERIFIED_PURCHASE": "verified", "RATING": "rating" })
df['product_id'] = df['product_id'].apply(lambda x: str(x)).astype(str)
df['product_title'] = df['product_title'].apply(lambda x: str(x)).astype(str)
df['rating'] = df['rating'].apply(lambda x: float(x))
df = df.drop(columns=["DOC_ID"])
df
# Out:
#             LABEL  rating verified PRODUCT_CATEGORY  product_id  \
# 0      __label1__     4.0        N               PC  B00008NG7N
# 1      __label1__     4.0        Y         Wireless  B00LH0Y3NM
# 2      __label1__     3.0        N             Baby  B000I5UZ1Q
# 3      __label1__     4.0        N  Office Products  B003822IRA
# 4      __label1__     4.0        N           Beauty  B00PWSAXAM
# ...           ...     ...      ...              ...         ...
# 20995  __label2__     4.0        Y            Shoes  B00BXYM8T8
# 20996  __label2__     4.0        Y            Shoes  B0014C2ORK
# 20997  __label2__     5.0        Y            Shoes  B000EX8CCQ
# 20998  __label2__     5.0        Y            Shoes  B00748YHVE
# 20999  __label2__     4.0        Y            Shoes  B00A46KTLU
#
#                                            product_title  \
# 0            Targus PAUK10U Ultra Mini USB Keypad, Black
# 1      Note 3 Battery : Stalion Strength Replacement ...
# 2           Fisher-Price Papasan Cradle Swing, Starlight
# 3      Casio MS-80B Standard Function Desktop Calculator
# 4      Shine Whitening - Zero Peroxide Teeth Whitenin...
# ...                                                  ...
# 20995  Madden Girl Women's Gettaw Pump,Red Patent,7.5...
# 20996  crocs Unisex Classic Clog,Khaki,6 US Men's / 8...
# 20997  Minnetonka Men's 703 Leather Laced Softsole Mo...
# 20998    Ariat Womens Unbridled Fatbaby 9 B Powder Brown
# 20999  VIBRAM FIVEFINGERS SPEED XC MENS HIKING SHOES,...
#
#                                             review_title  \
# 0                                                 useful
# 1                                  New era for batteries
# 2                               doesn't swing very well.
# 3                                       Great computing!
# 4                                  Only use twice a week
# ...                                                  ...
# 20995                               wide width is great!
# 20996                                        Love crocs!
# 20997  I love moccasins This fit like it was custom m...
# 20998        This fit well, comfortable, best investment
# 20999             Love these shoes, except for the laces
#
#                                              review_text
# 0      When least you think so, this product will sav...
# 1      Lithium batteries are something new introduced...
# 2      I purchased this swing for my baby. She is 6 m...
# 3      I was looking for an inexpensive desk calcolat...
# 4      I only use it twice a week and the results are...
# ...                                                  ...
# 20995  I bought these for work.  I have high arches, ...
# 20996  Crocs are one of only two brands of shoes that...
# 20997  I love moccasins  This fit like it was custom ...
# 20998  I wish these were a little more durable. I got...
# 20999  I've been looking for a replacement for my bel...
#
# [21000 rows x 8 columns]

# %%
reviews_scraped = pd.read_csv("data/product_reviews_scraped.csv", sep=",")
reviews_scraped["verified_purchase"] = np.where(reviews_scraped["verified_purchase"] == True, 1.0, 0.0)
reviews_scraped = reviews_scraped.rename(columns={"id": "product_id", "title": "review_title","content": "review_text", "verified_purchase": "verified", "rating": "rating" })
reviews_scraped['review_text'] = reviews_scraped['review_text'].apply(lambda x: str(x)).astype(str)
reviews_scraped['product_id'] = reviews_scraped['product_id'].apply(lambda x: str(x)).astype(str)
reviews_scraped
# Out:
#        product_id                                       review_title  \
# 0      0006486118  A Dance With Dragons (A Song of Ice and Fire, ...
# 1      0006486118  A Dance With Dragons (A Song of Ice and Fire, ...
# 2      0028703200  Research in Music Education: An Introduction t...
# 3      0028703200  Research in Music Education: An Introduction t...
# 4      0060159839                           James Mason: Odd Man Out
# ...           ...                                                ...
# 99884  B011MJ2JE2  PowerJive 800pc Laptop Screws Replacment Set R...
# 99885  B011MJ2JE2  PowerJive 800pc Laptop Screws Replacment Set R...
# 99886  B011MJ2JE2  PowerJive 800pc Laptop Screws Replacment Set R...
# 99887  B011MJ2JE2  PowerJive 800pc Laptop Screws Replacment Set R...
# 99888  B011MJ2JE2  PowerJive 800pc Laptop Screws Replacment Set R...
#
#        rating_count  rating_avg  rating1  rating2  rating3  rating4  rating5  \
# 0           17539.0         4.5     0.03     0.03     0.07     0.14     0.73
# 1           17539.0         4.5     0.03     0.03     0.07     0.14     0.73
# 2               7.0         4.8     0.00     0.00     0.00     0.23     0.77
# 3               7.0         4.8     0.00     0.00     0.00     0.23     0.77
# 4             279.0         3.9     0.03     0.09     0.18     0.33     0.36
# ...             ...         ...      ...      ...      ...      ...      ...
# 99884          46.0         4.4     0.12     0.00     0.00     0.17     0.71
# 99885          46.0         4.4     0.12     0.00     0.00     0.17     0.71
# 99886          46.0         4.4     0.12     0.00     0.00     0.17     0.71
# 99887          46.0         4.4     0.12     0.00     0.00     0.17     0.71
# 99888          46.0         4.4     0.12     0.00     0.00     0.17     0.71
#
#        helpful  verified                                        review_text  \
# 0            6       1.0  To preface this review, I wanted to inform you...
# 1           13       1.0  Fans have been looking forward to this one for...
# 2            0       1.0  Excellent book for me- I'm a bit rusty on rese...
# 3            0       0.0  It is a fantastic book because it deals specif...
# 4            0       1.0                          not the authors best work
# ...        ...       ...                                                ...
# 99884        0       1.0  Great set of laptop screws, found the 3 exact ...
# 99885        0       1.0  This is a nice assortment of hardware.  It's n...
# 99886        0       1.0  Yay! so happy to have all the screws i'll ever...
# 99887        0       1.0  Appears to be a very complete set of screws in...
# 99888        0       1.0  Bought these to replace several lost screws in...
#
#        rating
# 0           5
# 1           4
# 2           5
# 3           5
# 4           4
# ...       ...
# 99884       5
# 99885       5
# 99886       5
# 99887       5
# 99888       5
#
# [99889 rows x 13 columns]

# %%
products_scraped = pd.read_csv("data/products_scraped.csv", sep=",")
products_scraped = products_scraped.rename(columns={"title": "product_title", "id": "product_id"})
products_scraped['product_id'] = products_scraped['product_id'].apply(lambda x: str(x)).astype(str)
products_scraped['product_title'] = products_scraped['product_title'].apply(lambda x: str(x)).astype(str)
products_scraped
# Out:
#        product_id                                      product_title  \
# 0      0006486118  A Dance With Dragons (A Song of Ice and Fire, ...
# 1      0028703200  Research in Music Education: An Introduction t...
# 2      0060159839                           James Mason: Odd Man Out
# 3      0060657677  A Hunger for Healing: The Twelve Steps as a Cl...
# 4      006074068X  Death at La Fenice: A Commissario Guido Brunet...
# ...           ...                                                ...
# 16304  B010L57I3K  Garkit 6-pocket Vertical Garden Planter, Top Q...
# 16305  B010YZTOSO  S1 LED LCD (WVGA) Mini Video Projector - Inter...
# 16306  B01134P1LY  IVORY PURE Skin Whitening Max Glutathione 1500...
# 16307  B011JB92AM  3 Pack - Candy Molds &amp; Silicone Ice Cube T...
# 16308  B011MJ2JE2  PowerJive 800pc Laptop Screws Replacment Set R...
#
#        rating_count  rating_avg  rating1  rating2  rating3  rating4  rating5
# 0           17539.0         4.5     0.03     0.03     0.07     0.14     0.73
# 1               7.0         4.8     0.00     0.00     0.00     0.23     0.77
# 2             279.0         3.9     0.03     0.09     0.18     0.33     0.36
# 3             157.0         4.6     0.03     0.02     0.07     0.12     0.76
# 4            5284.0         4.4     0.01     0.02     0.10     0.31     0.56
# ...             ...         ...      ...      ...      ...      ...      ...
# 16304           NaN         2.0     0.00     1.00     0.00     0.00     0.00
# 16305         422.0         4.1     0.07     0.05     0.14     0.18     0.56
# 16306          88.0         3.8     0.14     0.06     0.18     0.13     0.49
# 16307          50.0         3.5     0.20     0.00     0.26     0.16     0.38
# 16308          46.0         4.4     0.12     0.00     0.00     0.17     0.71
#
# [16309 rows x 9 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
# one hot encode product category:
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(handle_unknown='ignore')
encoder_df = pd.DataFrame(encoder.fit_transform(df[['PRODUCT_CATEGORY']]).toarray())
encoder_df = encoder_df.rename(lambda x: f"cat_{x}", axis=1)
df = df.join(encoder_df)
CATEGORY_COLUMNS = [e for e in encoder_df.columns]
# encode verified purchase as y=1, n=0
df["verified"] = np.where(df["verified"] == "Y", 1.0, 0.0)
df["label"] = np.where(df["LABEL"] == "__label1__", 1.0, 0.0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\code\financial_technology\amazon-fake-reviews\preprocessing.ipynb Cell 6 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/d%3A/code/financial_technology/amazon-fake-reviews/preprocessing.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a> encoder_df = pd.DataFrame(encoder.fit_transform(df[['PRODUCT_CATEGORY']]).toarray())
#       <a href='vscode-notebook-cell:/d%3A/code/financial_technology/amazon-fake-reviews/preprocessing.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> encoder_df = encoder_df.rename(lambda x: f"cat_{x}", axis=1)
# ----> <a href='vscode-notebook-cell:/d%3A/code/financial_technology/amazon-fake-reviews/preprocessing.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a> df = df.join(encoder_df)
#       <a href='vscode-notebook-cell:/d%3A/code/financial_technology/amazon-fake-reviews/preprocessing.ipynb#X26sZmlsZQ%3D%3D?line=6'>7</a> CATEGORY_COLUMNS = [e for e in encoder_df.columns]
#       <a href='vscode-notebook-cell:/d%3A/code/financial_technology/amazon-fake-reviews/preprocessing.ipynb#X26sZmlsZQ%3D%3D?line=7'>8</a> # encode verified purchase as y=1, n=0
#
# File c:\Users\tadeo\anaconda3\lib\site-packages\pandas\core\frame.py:9966, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9803 def join(
#    9804     self,
#    9805     other: DataFrame | Series | list[DataFrame | Series],
#    (...)
#    9811     validate: str | None = None,
#    9812 ) -> DataFrame:
#    9813     """
#    9814     Join columns of another DataFrame.
#    9815
#    (...)
#    9964     5  K1  A5   B1
#    9965     """
# -> 9966     return self._join_compat(
#    9967         other,
#    9968         on=on,
#    9969         how=how,
#    9970         lsuffix=lsuffix,
#    9971         rsuffix=rsuffix,
#    9972         sort=sort,
#    9973         validate=validate,
#    9974     )
#
# File c:\Users\tadeo\anaconda3\lib\site-packages\pandas\core\frame.py:10005, in DataFrame._join_compat(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9995     if how == "cross":
#    9996         return merge(
#    9997             self,
#    9998             other,
#    (...)
#   10003             validate=validate,
#   10004         )
# > 10005     return merge(
#   10006         self,
#   10007         other,
#   10008         left_on=on,
#   10009         how=how,
#   10010         left_index=on is None,
#   10011         right_index=True,
#   10012         suffixes=(lsuffix, rsuffix),
#   10013         sort=sort,
#   10014         validate=validate,
#   10015     )
#   10016 else:
#   10017     if on is not None:
#
# File c:\Users\tadeo\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:124, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
#     110     op = _MergeOperation(
#     111         left,
#     112         right,
#    (...)
#     122         validate=validate,
#     123     )
# --> 124     return op.get_result(copy=copy)
#
# File c:\Users\tadeo\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:775, in _MergeOperation.get_result(self, copy)
#     771     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     773 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 775 result = self._reindex_and_concat(
#     776     join_index, left_indexer, right_indexer, copy=copy
#     777 )
#     778 result = result.__finalize__(self, method=self._merge_type)
#     780 if self.indicator:
#
# File c:\Users\tadeo\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:729, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     726 left = self.left[:]
#     727 right = self.right[:]
# --> 729 llabels, rlabels = _items_overlap_with_suffix(
#     730     self.left._info_axis, self.right._info_axis, self.suffixes
#     731 )
#     733 if left_indexer is not None:
#     734     # Pinning the index here (and in the right code just below) is not
#     735     #  necessary, but makes the `.take` more performant if we have e.g.
#     736     #  a MultiIndex for left.index.
#     737     lmgr = left._mgr.reindex_indexer(
#     738         join_index,
#     739         left_indexer,
#    (...)
#     744         use_na_proxy=True,
#     745     )
#
# File c:\Users\tadeo\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:2458, in _items_overlap_with_suffix(left, right, suffixes)
#    2455 lsuffix, rsuffix = suffixes
#    2457 if not lsuffix and not rsuffix:
# -> 2458     raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2460 def renamer(x, suffix):
#    2461     """
#    2462     Rename the left and right indices.
#    2463
#    (...)
#    2474     x : renamed column name
#    2475     """
#
# ValueError: columns overlap but no suffix specified: Index(['cat_0', 'cat_1', 'cat_2', 'cat_3', 'cat_4', 'cat_5', 'cat_6', 'cat_7',
#        'cat_8', 'cat_9', 'cat_10', 'cat_11', 'cat_12', 'cat_13', 'cat_14',
#        'cat_15', 'cat_16', 'cat_17', 'cat_18', 'cat_19', 'cat_20', 'cat_21',
#        'cat_22', 'cat_23', 'cat_24', 'cat_25', 'cat_26', 'cat_27', 'cat_28',
#        'cat_29'],
#       dtype='object')

# %%
df
# Out:
#        rating  verified PRODUCT_CATEGORY  product_id  \
# 0         4.0       0.0               PC  B00008NG7N
# 1         4.0       1.0         Wireless  B00LH0Y3NM
# 2         4.0       1.0         Wireless  B00LH0Y3NM
# 3         3.0       0.0             Baby  B000I5UZ1Q
# 4         4.0       0.0  Office Products  B003822IRA
# ...       ...       ...              ...         ...
# 18102     4.0       1.0            Shoes  B00BXYM8T8
# 18103     4.0       1.0            Shoes  B0014C2ORK
# 18104     5.0       1.0            Shoes  B000EX8CCQ
# 18105     5.0       1.0            Shoes  B00748YHVE
# 18106     4.0       1.0            Shoes  B00A46KTLU
#
#                                             review_title  \
# 0                                                 useful
# 1                                  New era for batteries
# 2                                                     OK
# 3                               doesn't swing very well.
# 4                                       Great computing!
# ...                                                  ...
# 18102                               wide width is great!
# 18103                                        Love crocs!
# 18104  I love moccasins This fit like it was custom m...
# 18105        This fit well, comfortable, best investment
# 18106             Love these shoes, except for the laces
#
#                                              review_text  cat_0  cat_1  cat_2  \
# 0      When least you think so, this product will sav...    0.0    0.0    0.0
# 1      Lithium batteries are something new introduced...    0.0    0.0    0.0
# 2      Seems to perform just ok, it's a battery. Came...    0.0    0.0    0.0
# 3      I purchased this swing for my baby. She is 6 m...    0.0    0.0    1.0
# 4      I was looking for an inexpensive desk calcolat...    0.0    0.0    0.0
# ...                                                  ...    ...    ...    ...
# 18102  I bought these for work.  I have high arches, ...    0.0    0.0    0.0
# 18103  Crocs are one of only two brands of shoes that...    0.0    0.0    0.0
# 18104  I love moccasins  This fit like it was custom ...    0.0    0.0    0.0
# 18105  I wish these were a little more durable. I got...    0.0    0.0    0.0
# 18106  I've been looking for a replacement for my bel...    0.0    0.0    0.0
#
#        cat_3  ...  text_sentiment  text_subjectivity  rating_count  \
# 0        0.0  ...       -0.300000           0.400000         233.0
# 1        0.0  ...        0.219226           0.385320         214.0
# 2        0.0  ...        0.477778           0.611111         214.0
# 3        0.0  ...        0.347143           0.600000         923.0
# 4        0.0  ...       -0.088542           0.441667       11026.0
# ...      ...  ...             ...                ...           ...
# 18102    0.0  ...        0.160000           0.540000        2350.0
# 18103    0.0  ...        0.177083           0.441667        7229.0
# 18104    0.0  ...        0.196049           0.428395        2439.0
# 18105    0.0  ...        0.302500           0.460000          10.0
# 18106    0.0  ...        0.167708           0.403632          11.0
#
#        rating_avg  rating1  rating2  rating3  rating4  rating5  \
# 0             4.6     0.03     0.01     0.07     0.07     0.81
# 1             3.8     0.17     0.06     0.14     0.11     0.53
# 2             3.8     0.17     0.06     0.14     0.11     0.53
# 3             4.4     0.06     0.03     0.08     0.07     0.76
# 4             4.8     0.01     0.01     0.03     0.10     0.85
# ...           ...      ...      ...      ...      ...      ...
# 18102         4.0     0.07     0.08     0.14     0.20     0.51
# 18103         4.7     0.02     0.01     0.03     0.08     0.86
# 18104         4.5     0.04     0.02     0.06     0.13     0.74
# 18105         4.0     0.14     0.00     0.17     0.13     0.56
# 18106         4.1     0.00     0.00     0.37     0.17     0.46
#
#                                            product_title
# 0            Targus PAUK10U Ultra Mini USB Keypad, Black
# 1      Note 3 Battery : Stalion Strength Replacement ...
# 2      Note 3 Battery : Stalion Strength Replacement ...
# 3           Fisher-Price Papasan Cradle Swing, Starlight
# 4      Casio MS-80B Standard Function Desktop Calculator
# ...                                                  ...
# 18102  Madden Girl Women's Gettaw Pump,Red Patent,7.5...
# 18103  crocs Unisex Classic Clog,Khaki,6 US Men's / 8...
# 18104  Minnetonka Men's 703 Leather Laced Softsole Mo...
# 18105    Ariat Womens Unbridled Fatbaby 9 B Powder Brown
# 18106  VIBRAM FIVEFINGERS SPEED XC MENS HIKING SHOES,...
#
# [18107 rows x 47 columns]

# %%
# export product ids:
f = open("data/ids.txt", "w+")
f.write("\n".join([e for e in df["product_id"]]))
f.close()

# %% [markdown]
# ## Feature Engineering

# %%
# sentiment analysis scores
from textblob import TextBlob

def get_polarity(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity

def get_subjectivity(text):
    blob = TextBlob(text)
    return blob.sentiment.subjectivity

# %%
# Sentiment Score for Review tex in df
df['text_sentiment'] = df['review_text'].apply(get_polarity)
df['text_subjectivity'] = df['review_text'].apply(get_subjectivity)

# %%
# Sentiment Score for Review tex in df
reviews_scraped['text_sentiment'] = reviews_scraped['review_text'].apply(get_polarity)
reviews_scraped['text_subjectivity'] = reviews_scraped['review_text'].apply(get_subjectivity)

# %%
df = df.merge(products_scraped, on=["product_id"])

# %%
df["product_title"] = df["product_title_x"]
df = df.drop(columns=["LABEL", "product_title_x", "product_title_y"])

# %% [markdown]
# # Saving the data:

# %%
df.to_csv("data/transformed/df.csv")
reviews_scraped.to_csv("data/transformed/reviews_scraped.csv")
